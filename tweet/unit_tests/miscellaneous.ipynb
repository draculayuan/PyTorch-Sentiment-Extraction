# %%
from transformers import BertTokenizer
# Out:
# I0513 00:56:01.091511 140701116851968 file_utils.py:41] PyTorch version 1.0.0 available.

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
# Out:
# I0513 00:56:18.206451 140701116851968 tokenization_utils.py:504] loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /home/liu/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084

# %%
trial = 'www.http.come hahaha'

# %%
ids = tokenizer.encode(trial)

# %%
text = tokenizer.tokenize(trial)

# %%
ids, text
# Out:
# ([101, 7479, 1012, 8299, 1012, 2272, 5292, 3270, 3270, 102],
#  ['www', '.', 'http', '.', 'come', 'ha', '##ha', '##ha'])

# %%
tokenizer.decode(ids)
# Out:
# '[CLS] www. http. come hahaha [SEP]'

# %%
import pandas as pd

# %%
result = pd.read_csv('../../infer/baseline_5k.csv')

# %%
result
# Out:
#       Unnamed: 0      textID  \
# 0              1  9e38c183ad
# 1              2  d1c010cd47
# 2              3  03c0b749b5
# 3              4  99f4063cf1
# 4              5  9d605483af
# 5              6  adede39756
# 6              7  9655b72897
# 7              8  52c7993b04
# 8              9  2ed155359e
# 9             10  18910017a3
# 10            11  6f0f3669ee
# 11            12  67564814b3
# 12            13  55644d8682
# 13            14  ddc928067a
# 14            15  ce4f7c4a1c
# 15            16  719f6bacc1
# 16            17  63a5bb931c
# 17            18  54591b7521
# 18            19  9197df16e5
# 19            20  33ea2ecd0c
# 20            21  028d57dc98
# 21            22  20c9c1300d
# 22            23  d2905a1a74
# 23            24  2385a6b7ea
# 24            25  670b6eef13
# 25            26  143d5c2a90
# 26            27  0da29ca73f
# 27            28  f8420ce323
# 28            29  c29e6cf197
# 29            30  80666ae17f
# ...          ...         ...
# 7451        7452  16947b5a23
# 7452        7453  af9f223e1f
# 7453        7454  a01e5d1ddf
# 7454        7455  465b9edc97
# 7455        7456  768e382964
# 7456        7457  d32efe060f
# 7457        7458  58804bf427
# 7458        7459  ea8072c6a6
# 7459        7460  13e1519ce3
# 7460        7461  17c8c317f0
# 7461        7462  c37b979e7e
# 7462        7463  3f9912ec7a
# 7463        7464  a38bf809b0
# 7464        7465  e7eecffdc8
# 7465        7466  c14a543497
# 7466        7467  7e8b34de71
# 7467        7468  432e6de6c9
# 7468        7469  a753a93e45
# 7469        7470  ac92790d8b
# 7470        7471  778184dff1
# 7471        7472  15bb120f57
# 7472        7473  8f5adc47ec
# 7473        7474  a208770a32
# 7474        7475  8f14bb2715
# 7475        7476  b78ec00df5
# 7476        7477  4eac33d1c0
# 7477        7478  4f4c4fc327
# 7478        7479  f67aae2310
# 7479        7480  ed167662a5
# 7480        7481  6f7127d9d7
#
#                                           selected_text
# 0     really thinks wee callum should of got through...
# 1     once again another late night. but i scored a ...
# 2      nooo i wanna watch the comet dont wanna go workk
# 3     i wish they had just bought it for me! never mind
# 4     mc john sim posit 3 yr passed no softees stran...
# 5     you look smashing darling is trent reznor real...
# 6                                 its bout smoking weed
# 7     it ` s official nobody is getting a raise this...
# 8     thank you all for your incredible support and ...
# 9     josette.... where are you?? i looked across th...
# 10             special chocr makin rounds @ gourds show
# 11                                                 miss
# 12                              sanitized and all good.
# 13      hello. new follower lang po. tweet to meet you.
# 14                                   i love him! thanks
# 15     mm it was cold in your shadow anyway. ooh monday
# 16                                       i hate packing
# 17                                               lovely
# 18                                                 hate
# 19             i suppose i best get ready for work grrr
# 20             aaaaw no! are the windows open and that?
# 21                                                happy
# 22    raining in belfast too - and i promised myself...
# 23                                         missing tim!
# 24                                 happy mother ` s day
# 25             ' no more sorrow '! by : linkin park....
# 26    sleep time big / little lunch tomorrow at oliv...
# 27                                               broken
# 28                              yep! tail between legs!
# 29    everybody wake the * * * * up!!! * flicks on e...
# ...                                                 ...
# 7451   happy all my studying and all nighters payed off
# 7452  so much for a day off - i ` ve been on my feet...
# 7453                             it ` s beeen onee year
# 7454                                               love
# 7455  lighten our mood, doesn ` * * * * ever happen ...
# 7456     i wanna leave work already! not feelin it 2day
# 7457                              my camera is brokennn
# 7458                                               wish
# 7459                                           good as,
# 7460  scream just played on my ipod. first thing tha...
# 7461                                               best
# 7462                                                fun
# 7463  like drew said'give tc a chance'we will miss t...
# 7464  pain is to much.. i need him... can ` t lose h...
# 7465                                              enjoy
# 7466  naw.. it was pretty tame. only 1 guy in costum...
# 7467                                            welcome
# 7468  few grilled mushrooms and olives, feta cheese ...
# 7469              94 more days till bh comes back to la
# 7470                                              bored
# 7471  i ` m defying gravity. and nobody in alll of o...
# 7472                                           too late
# 7473  in spoke to you yesterday and u didnt respond ...
# 7474  i feel good about the day. i walk to work and ...
# 7475                                     enjoy ur night
# 7476  wish we could come see u on denver husband los...
# 7477  i ` ve wondered about rake to. the client has ...
# 7478              good for both of you. enjoy the break
# 7479                                              worth
# 7480  all this flirting going on - the atg smiles. y...
#
# [7481 rows x 3 columns]
